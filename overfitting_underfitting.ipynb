# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
melbourne_file_path="melb_data.csv"
melbourne_data=pd.read_csv(melbourne_file_path)

# %%
def get_mae(max_leaf_nodes,train_X,val_X,train_y,val_y):
    model=DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=1)
    model.fit(train_X,train_y)
    val_predction=model.predict(val_X)
    mae=mean_absolute_error(val_y,val_predction)
    return mae

# %%
#target
y=melbourne_data.Price
#Add features
melbourne_features=['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X=melbourne_data[melbourne_features]
train_X,val_X,train_y,val_y=train_test_split(X,y,random_state=1)

# %%
for max_leaf_nodes in [5,50,500,5000]:
    my_mae=get_mae(max_leaf_nodes,train_X,val_X,train_y,val_y)
    print(f"Max Leaf Nodes: {max_leaf_nodes} \t Mean Absolute Error: {my_mae}")
# Out:
# Max Leaf Nodes: 5 	 Mean Absolute Error: 356157.8826013371
# Max Leaf Nodes: 50 	 Mean Absolute Error: 264538.5759958539
# Max Leaf Nodes: 500 	 Mean Absolute Error: 221700.64446737713
# Max Leaf Nodes: 5000 	 Mean Absolute Error: 239472.1370574522
